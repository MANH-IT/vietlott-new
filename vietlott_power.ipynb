# %%
! pip install pandas numpy prophet tensorflow scikit-learn matplotlib
# Out:
# Requirement already satisfied: pandas in .\vietlott_new\lib\site-packages (2.3.0)
# Requirement already satisfied: numpy in .\vietlott_new\lib\site-packages (2.1.3)
# Requirement already satisfied: prophet in .\vietlott_new\lib\site-packages (1.1.7)
# Requirement already satisfied: tensorflow in .\vietlott_new\lib\site-packages (2.19.0)
# Requirement already satisfied: scikit-learn in .\vietlott_new\lib\site-packages (1.7.0)
# Requirement already satisfied: matplotlib in .\vietlott_new\lib\site-packages (3.10.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\vietlott_new\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in .\vietlott_new\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in .\vietlott_new\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: cmdstanpy>=1.0.4 in .\vietlott_new\lib\site-packages (from prophet) (1.2.5)
# Requirement already satisfied: holidays<1,>=0.25 in .\vietlott_new\lib\site-packages (from prophet) (0.75)
# Requirement already satisfied: tqdm>=4.36.1 in .\vietlott_new\lib\site-packages (from prophet) (4.67.1)
# Requirement already satisfied: importlib_resources in .\vietlott_new\lib\site-packages (from prophet) (6.5.2)
# Requirement already satisfied: absl-py>=1.0.0 in .\vietlott_new\lib\site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in .\vietlott_new\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in .\vietlott_new\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in .\vietlott_new\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in .\vietlott_new\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in .\vietlott_new\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in .\vietlott_new\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in .\vietlott_new\lib\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in .\vietlott_new\lib\site-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in .\vietlott_new\lib\site-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in .\vietlott_new\lib\site-packages (from tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in .\vietlott_new\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in .\vietlott_new\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in .\vietlott_new\lib\site-packages (from tensorflow) (4.14.0)
# Requirement already satisfied: wrapt>=1.11.0 in .\vietlott_new\lib\site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in .\vietlott_new\lib\site-packages (from tensorflow) (1.73.0)
# Requirement already satisfied: tensorboard~=2.19.0 in .\vietlott_new\lib\site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in .\vietlott_new\lib\site-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: h5py>=3.11.0 in .\vietlott_new\lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in .\vietlott_new\lib\site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in .\vietlott_new\lib\site-packages (from tensorflow) (0.31.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\vietlott_new\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in .\vietlott_new\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\vietlott_new\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in .\vietlott_new\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.6.15)
# Requirement already satisfied: markdown>=2.6.8 in .\vietlott_new\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in .\vietlott_new\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in .\vietlott_new\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: scipy>=1.8.0 in .\vietlott_new\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in .\vietlott_new\lib\site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in .\vietlott_new\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in .\vietlott_new\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in .\vietlott_new\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in .\vietlott_new\lib\site-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in .\vietlott_new\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in .\vietlott_new\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in .\vietlott_new\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in .\vietlott_new\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in .\vietlott_new\lib\site-packages (from cmdstanpy>=1.0.4->prophet) (0.5.1)
# Requirement already satisfied: rich in .\vietlott_new\lib\site-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: namex in .\vietlott_new\lib\site-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in .\vietlott_new\lib\site-packages (from keras>=3.5.0->tensorflow) (0.16.0)
# Requirement already satisfied: colorama in .\vietlott_new\lib\site-packages (from tqdm>=4.36.1->prophet) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.1.1 in .\vietlott_new\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in .\vietlott_new\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in .\vietlott_new\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in .\vietlott_new\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %%
import pandas as pd
import logging

# Thiết lập logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Đường dẫn file
input_path = r'E:\vietlott_new\data_power\data.csv'

try:
    # Đọc file CSV
    df = pd.read_csv(
        input_path,
        encoding='utf-8',
        sep='\t',  # Dấu tab làm phân tách
        on_bad_lines='skip',  # Bỏ qua dòng lỗi
        quoting=3,  # Không xử lý dấu ngoặc kép
    )
    
    # Loại bỏ khoảng trắng thừa trong tên cột
    df.columns = df.columns.str.strip()
    
    # Ghi log tên cột để kiểm tra
    logging.info("Các cột trong file CSV: %s", df.columns.tolist())
    
    # Kiểm tra và xóa cột 'Giải Jackpot 2'
    if 'Giải Jackpot 2' in df.columns:
        df = df.drop('Giải Jackpot 2', axis=1)
        logging.info("Đã xóa cột 'Giải Jackpot 2' thành công.")
        
        # Lưu DataFrame đã chỉnh sửa vào file CSV
        df.to_csv(input_path, index=False, encoding='utf-8', sep='\t')
        logging.info("Đã lưu file CSV đã chỉnh sửa vào %s", input_path)
    else:
        logging.error("Không tìm thấy cột 'Giải Jackpot 2' trong file CSV.")
        
except Exception as e:
    logging.error("Có lỗi xảy ra: %s", str(e))
# Out:
# 2025-06-21 14:10:22,989 - INFO - Các cột trong file CSV: ['Ngày Mở Thưởng', 'Kết Quả', 'Giải Jackpot 1', 'Giải Jackpot 2']
# 2025-06-21 14:10:22,992 - INFO - Đã xóa cột 'Giải Jackpot 2' thành công.
# 2025-06-21 14:10:23,001 - INFO - Đã lưu file CSV đã chỉnh sửa vào E:\vietlott_new\data_power\data.csv

# %%
import pandas as pd
import logging

# Thiết lập logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Đường dẫn file
input_path = r'E:\vietlott_new\data_power\data.csv'

try:
    # Đọc file CSV
    df = pd.read_csv(
        input_path,
        encoding='utf-8',
        sep='\t',  # Dấu tab làm phân tách
        on_bad_lines='skip',  # Bỏ qua dòng lỗi
        quoting=3,  # Không xử lý dấu ngoặc kép
    )
except Exception as e:
    logging.error(f"Lỗi khi đọc file: {e}")
    exit()

# Loại bỏ khoảng trắng thừa trong tên cột
df.columns = df.columns.str.strip()

# Xóa cột 'Giải Jackpot 2'
if 'Giải Jackpot 2' in df.columns:
    df = df.drop('Giải Jackpot 2', axis=1)
    logging.info("Đã xóa cột 'Giải Jackpot 2' thành công.")
else:
    logging.warning("Cột 'Giải Jackpot 2' không tồn tại trong file CSV.")

# 1. Xác định số cột và số hàng
num_rows, num_cols = df.shape
print(f"Số hàng: {num_rows}")
print(f"Số cột: {num_cols}")
print("\nTên các cột:", list(df.columns))

# 2. In 20 hàng đầu tiên
print("\n20 hàng đầu tiên:")
print(df.head(20).to_string(index=False))

# 3. In 20 hàng cuối cùng
print("\n20 hàng cuối cùng:")
print(df.tail(20).to_string(index=False))

# 4. Làm sạch dữ liệu (kiểm tra giá trị thiếu)
print("\nThông tin dữ liệu:")
print(df.info())
print("\nSố giá trị thiếu trong mỗi cột:")
print(df.isnull().sum())

# 5. Tách cột Kết Quả thành 6 số chính (bỏ số thưởng)
def parse_results(result):
    try:
        # Lấy 6 số đầu tiên (bỏ số thưởng)
        numbers = [int(x) for x in result.split()[:6]]
        return numbers
    except:
        return [None] * 6

df['Numbers'] = df['Kết Quả'].apply(parse_results)
df[['Num1', 'Num2', 'Num3', 'Num4', 'Num5', 'Num6']] = pd.DataFrame(df['Numbers'].tolist(), index=df.index)

# Kiểm tra dữ liệu sau khi tách
print("\nDữ liệu sau khi tách cột Kết Quả (5 hàng đầu tiên):")
print(df[['Ngày Mở Thưởng', 'Num1', 'Num2', 'Num3', 'Num4', 'Num5', 'Num6']].head().to_string(index=False))

# Lưu DataFrame đã chỉnh sửa vào file CSV
try:
    df.to_csv(input_path, index=False, encoding='utf-8', sep='\t')
    logging.info("Đã lưu file CSV đã chỉnh sửa vào %s", input_path)
except Exception as e:
    logging.error(f"Lỗi khi lưu file: {e}")
# Out:
# 2025-06-21 14:11:37,626 - WARNING - Cột 'Giải Jackpot 2' không tồn tại trong file CSV.
# 2025-06-21 14:11:37,690 - INFO - Đã lưu file CSV đã chỉnh sửa vào E:\vietlott_new\data_power\data.csv
# Số hàng: 1205
# Số cột: 3
#
# Tên các cột: ['Ngày Mở Thưởng', 'Kết Quả', 'Giải Jackpot 1']
#
# 20 hàng đầu tiên:
# Ngày Mở Thưởng              Kết Quả  Giải Jackpot 1
# T5, 19/06/2025 03 05 09 10 16 47 34    Chờ thống kê
# T3, 17/06/2025 07 13 18 22 32 44 43 243.233.929.650
# T7, 14/06/2025 11 12 22 26 41 47 24 233.787.794.700
# T5, 12/06/2025 06 08 16 18 34 44 17 224.635.393.650
# T3, 10/06/2025 03 06 21 29 40 41 37 216.184.106.550
# T7, 07/06/2025 12 17 21 46 48 52 45 202.986.697.350
# T5, 05/06/2025 14 21 33 37 46 49 34 191.760.348.000
# T3, 03/06/2025 02 11 14 16 27 38 51 180.795.936.450
# T7, 31/05/2025 06 24 41 45 49 55 08 170.827.938.300
# T5, 29/05/2025 09 37 42 45 46 50 14 160.738.006.800
# T3, 27/05/2025 04 12 18 19 44 48 42 153.441.786.900
# T7, 24/05/2025 19 20 27 30 45 55 15 146.813.952.000
# T5, 22/05/2025 03 09 14 41 47 55 22 140.519.788.050
# T3, 20/05/2025 19 27 44 45 47 52 15 134.006.693.250
# T7, 17/05/2025 02 07 26 29 41 50 43 124.379.568.750
# T5, 15/05/2025 06 09 13 44 49 54 47 115.812.032.250
# T3, 13/05/2025 03 07 24 39 54 55 42 108.136.393.500
# T7, 10/05/2025 07 16 19 28 34 51 15  99.353.641.350
# T5, 08/05/2025 08 14 29 37 39 50 21  92.683.982.550
# T3, 06/05/2025 12 16 25 28 30 39 05  89.374.369.800
#
# 20 hàng cuối cùng:
# Ngày Mở Thưởng              Kết Quả Giải Jackpot 1
# T5, 14/09/2017 22 23 32 43 44 51 15 52.263.240.150
# T3, 12/09/2017 06 10 12 47 48 51 35 51.063.730.500
# T7, 09/09/2017 01 15 23 36 43 54 12 49.441.033.650
# T5, 07/09/2017 04 18 22 31 32 40 08 48.190.895.850
# T3, 05/09/2017 01 02 08 13 23 39 09 46.972.594.200
# T7, 02/09/2017 05 09 11 18 19 37 50 45.743.789.550
# T5, 31/08/2017 08 20 27 35 36 47 18 45.086.515.950
# T3, 29/08/2017 04 12 15 23 24 41 44 43.925.548.800
# T7, 26/08/2017 17 25 30 31 36 41 20 42.705.608.250
# T5, 24/08/2017 05 16 18 37 42 46 10 41.355.943.950
# T3, 22/08/2017 10 24 31 32 38 44 14 40.231.270.200
# T7, 19/08/2017 07 11 13 15 26 51 36 38.842.141.350
# T5, 17/08/2017 11 12 20 30 32 34 53 37.754.634.900
# T3, 15/08/2017 07 11 19 32 33 51 30 36.713.676.000
# T7, 12/08/2017 06 16 20 32 38 51 34 35.666.199.750
# T5, 10/08/2017 10 11 19 41 50 54 03 34.588.091.550
# T3, 08/08/2017 19 36 39 41 46 51 38 33.415.353.750
# T7, 05/08/2017 01 05 11 32 40 45 43 31.903.413.600
# T5, 03/08/2017 04 09 24 25 27 45 40 31.024.813.350
# T3, 01/08/2017 05 10 14 23 24 38 35 30.528.493.950
#
# Thông tin dữ liệu:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1205 entries, 0 to 1204
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Ngày Mở Thưởng  1205 non-null   object
#  1   Kết Quả         1205 non-null   object
#  2   Giải Jackpot 1  1205 non-null   object
# dtypes: object(3)
# memory usage: 28.4+ KB
# None
#
# Số giá trị thiếu trong mỗi cột:
# Ngày Mở Thưởng    0
# Kết Quả           0
# Giải Jackpot 1    0
# dtype: int64
#
# Dữ liệu sau khi tách cột Kết Quả (5 hàng đầu tiên):
# Ngày Mở Thưởng  Num1  Num2  Num3  Num4  Num5  Num6
# T5, 19/06/2025     3     5     9    10    16    47
# T3, 17/06/2025     7    13    18    22    32    44
# T7, 14/06/2025    11    12    22    26    41    47
# T5, 12/06/2025     6     8    16    18    34    44
# T3, 10/06/2025     3     6    21    29    40    41

# %%
import pandas as pd
import numpy as np
import logging
from datetime import datetime

# Thiết lập logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler('E:/vietlott_new/data_power/process_log.txt', encoding='utf-8'),
        logging.StreamHandler()
    ]
)

# Đường dẫn file
input_path = r'E:\vietlott_new\data_power\data.csv'
output_path = r'E:\vietlott_new\data_power\data_clean.csv'
output_features_path = r'E:\vietlott_new\data_power\data_clean_with_features.csv'

# Đọc file
try:
    df = pd.read_csv(
        input_path,
        encoding='utf-8',
        sep='\t',
        on_bad_lines='skip',
        quoting=3,
    )
    logging.info("Tệp được tải thành công. Danh sách cột: %s", list(df.columns))
except FileNotFoundError:
    logging.error("Không tìm thấy tệp tại %s", input_path)
    exit()
except UnicodeDecodeError:
    logging.error("Lỗi mã hóa, thử với utf-8-sig")
    df = pd.read_csv(input_path, encoding='utf-8-sig', sep='\t', on_bad_lines='skip', quoting=3)
except Exception as e:
    logging.error("Lỗi khi đọc file: %s", e)
    exit()

# Làm sạch tên cột
df.columns = [col.strip() for col in df.columns]

# Xóa cột 'Giải Jackpot 2' nếu có
if 'Giải Jackpot 2' in df.columns:
    df = df.drop('Giải Jackpot 2', axis=1)
    logging.info("Đã xóa cột 'Giải Jackpot 2' thành công.")
else:
    logging.info("Cột 'Giải Jackpot 2' không tồn tại trong file CSV.")

# Hàm tách cột Kết Quả thành 6 số chính (bỏ số thưởng) và kiểm tra tính hợp lệ
def parse_results(result):
    try:
        numbers = [int(x) for x in str(result).split()[:6]]  # Lấy 6 số chính
        # Kiểm tra số lượng và giá trị hợp lệ (1-55 cho Power 6/55)
        if len(numbers) == 6 and all(1 <= x <= 55 for x in numbers):
            return numbers
        return [np.nan] * 6
    except:
        return [np.nan] * 6

# Tách cột Kết Quả nếu chưa có các cột Num1-Num6
if 'Kết Quả' in df.columns and not all(col in df.columns for col in ['Num1', 'Num2', 'Num3', 'Num4', 'Num5', 'Num6']):
    df['Numbers'] = df['Kết Quả'].apply(parse_results)
    df[['Num1', 'Num2', 'Num3', 'Num4', 'Num5', 'Num6']] = pd.DataFrame(df['Numbers'].tolist(), index=df.index)
    df = df.drop(columns=['Numbers', 'Kết Quả'], errors='ignore')
    logging.info("Đã tách cột Kết Quả thành Num1-Num6.")
else:
    if 'Kết Quả' not in df.columns:
        logging.error("Cột 'Kết Quả' không tồn tại")
        exit()
    else:
        logging.info("Các cột Num1-Num6 đã tồn tại, bỏ qua bước tách Kết Quả.")

# Xử lý cột Ngày Mở Thưởng
def parse_date(date_str):
    try:
        # Chuyển định dạng T6, 13/06/2025 sang datetime
        date_str = date_str.split(', ')[1]
        return pd.to_datetime(date_str, format='%d/%m/%Y')
    except:
        return pd.NaT

if 'Ngày Mở Thưởng' in df.columns:
    df['Ngày Mở Thưởng'] = df['Ngày Mở Thưởng'].apply(parse_date)
else:
    logging.error("Cột 'Ngày Mở Thưởng' không tồn tại")
    exit()

# Xử lý cột Giải Jackpot 1
def clean_jackpot(jackpot):
    try:
        # Loại bỏ dấu chấm và chuyển sang số nguyên
        if isinstance(jackpot, str) and jackpot != 'Chờ thống kê':
            return int(jackpot.replace('.', ''))
        return np.nan
    except:
        return np.nan

if 'Giải Jackpot 1' in df.columns:
    df['Giải Jackpot 1'] = df['Giải Jackpot 1'].apply(clean_jackpot)
    logging.info("Đã làm sạch cột Giải Jackpot 1.")
else:
    logging.error("Cột 'Giải Jackpot 1' không tồn tại")
    exit()

# Kiểm tra và loại bỏ hàng có giá trị thiếu
initial_rows = df.shape[0]
df = df.dropna()
logging.info("Loại bỏ %d hàng có giá trị thiếu", initial_rows - df.shape[0])

# Kiểm tra trùng lặp
duplicates = df.duplicated().sum()
if duplicates > 0:
    df = df.drop_duplicates()
    logging.info("Loại bỏ %d hàng trùng lặp", duplicates)

# Sắp xếp dữ liệu theo ngày
df = df.sort_values('Ngày Mở Thưởng', ascending=False)

# Sắp xếp lại thứ tự cột
desired_columns = ['Ngày Mở Thưởng', 'Num1', 'Num2', 'Num3', 'Num4', 'Num5', 'Num6', 'Giải Jackpot 1']
df = df[[col for col in desired_columns if col in df.columns]]

# In thông tin dữ liệu
logging.info("Số hàng: %d", df.shape[0])
logging.info("Số cột: %d", df.shape[1])
logging.info("Tên các cột: %s", list(df.columns))
logging.info("\n5 hàng đầu tiên:\n%s", df.head().to_string(index=False))

# Kiểm tra giá trị thiếu
logging.info("\nSố giá trị thiếu trong mỗi cột:\n%s", df.isnull().sum())

# Lưu dữ liệu sạch
try:
    df.to_csv(output_path, index=False, encoding='utf-8', sep='\t')
    logging.info("Dữ liệu đã được lưu vào %s", output_path)
except Exception as e:
    logging.error("Lỗi khi lưu file: %s", e)

# Thêm các cột đặc trưng (feature engineering)
df['Sum'] = df[['Num1', 'Num2', 'Num3', 'Num4', 'Num5', 'Num6']].sum(axis=1)
df['Mean'] = df[['Num1', 'Num2', 'Num3', 'Num4', 'Num5', 'Num6']].mean(axis=1)
df['Std'] = df[['Num1', 'Num2', 'Num3', 'Num4', 'Num5', 'Num6']].std(axis=1)

# Lưu dữ liệu với các đặc trưng bổ sung
try:
    df.to_csv(output_features_path, index=False, encoding='utf-8', sep='\t')
    logging.info("Dữ liệu với các đặc trưng bổ sung đã được lưu vào %s", output_features_path)
except Exception as e:
    logging.error("Lỗi khi lưu file đặc trưng: %s", e)
# Out:
# 2025-06-21 14:17:42,879 - INFO - Tệp được tải thành công. Danh sách cột: ['Ngày Mở Thưởng', 'Kết Quả', 'Giải Jackpot 1', 'Numbers', 'Num1', 'Num2', 'Num3', 'Num4', 'Num5', 'Num6']
# 2025-06-21 14:17:42,883 - INFO - Cột 'Giải Jackpot 2' không tồn tại trong file CSV.
# 2025-06-21 14:17:42,886 - INFO - Các cột Num1-Num6 đã tồn tại, bỏ qua bước tách Kết Quả.
# 2025-06-21 14:17:42,999 - INFO - Đã làm sạch cột Giải Jackpot 1.
# 2025-06-21 14:17:43,001 - INFO - Loại bỏ 1 hàng có giá trị thiếu
# 2025-06-21 14:17:43,006 - INFO - Số hàng: 1204
# 2025-06-21 14:17:43,007 - INFO - Số cột: 8
# 2025-06-21 14:17:43,007 - INFO - Tên các cột: ['Ngày Mở Thưởng', 'Num1', 'Num2', 'Num3', 'Num4', 'Num5', 'Num6', 'Giải Jackpot 1']
# 2025-06-21 14:17:43,011 - INFO -
# 5 hàng đầu tiên:
# Ngày Mở Thưởng  Num1  Num2  Num3  Num4  Num5  Num6  Giải Jackpot 1
#     2025-06-17     7    13    18    22    32    44    2.432339e+11
#     2025-06-14    11    12    22    26    41    47    2.337878e+11
#     2025-06-12     6     8    16    18    34    44    2.246354e+11
#     2025-06-10     3     6    21    29    40    41    2.161841e+11
#     2025-06-07    12    17    21    46    48    52    2.029867e+11
# 2025-06-21 14:17:43,012 - INFO -
# Số giá trị thiếu trong mỗi cột:
# Ngày Mở Thưởng    0
# Num1              0
# Num2              0
# Num3              0
# Num4              0
# Num5              0
# Num6              0
# Giải Jackpot 1    0
# dtype: int64
# 2025-06-21 14:17:43,018 - INFO - Dữ liệu đã được lưu vào E:\vietlott_new\data_power\data_clean.csv
# 2025-06-21 14:17:43,029 - INFO - Dữ liệu với các đặc trưng bổ sung đã được lưu vào E:\vietlott_new\data_power\data_clean_with_features.csv

# %%
import pandas as pd
import numpy as np
from collections import Counter
from itertools import combinations
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import f1_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping
import logging
from datetime import datetime, timedelta

# Thiết lập logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler('E:/vietlott_new/data_power/predict_log.txt', encoding='utf-8'),
        logging.StreamHandler()
    ]
)

# Đường dẫn file dữ liệu
input_path = 'E:/vietlott_new/data_power/data_clean.csv'.replace('\\', '/')
output_predictions_path = 'E:/vietlott_new/data_power/predictions.csv'.replace('\\', '/')

# Hàm đọc dữ liệu
def load_data(path):
    try:
        df = pd.read_csv(path, encoding='utf-8', sep='\t')
        if df.empty:
            logging.error("Dữ liệu rỗng hoặc không đọc được.")
            return None
        return df
    except FileNotFoundError:
        logging.error("Không tìm thấy file: %s", path)
        return None
    except Exception as e:
        logging.error("Lỗi khi đọc file: %s", e)
        return None

# Đọc dữ liệu
df = load_data(input_path)
if df is None:
    exit()

# Kiểm tra cột cần thiết
required_columns = ['Ngày Mở Thưởng', 'Num1', 'Num2', 'Num3', 'Num4', 'Num5', 'Num6']
if not all(col in df.columns for col in required_columns):
    logging.error("File CSV thiếu các cột cần thiết: %s", required_columns)
    exit()

# Xóa cột 'Giải Jackpot 2' nếu có
if 'Giải Jackpot 2' in df.columns:
    df = df.drop('Giải Jackpot 2', axis=1)
    logging.info("Đã xóa cột 'Giải Jackpot 2' thành công.")

# Kiểm tra dữ liệu không hợp lệ
invalid_rows = df[['Num1', 'Num2', 'Num3', 'Num4', 'Num5', 'Num6']].apply(lambda x: (~x.between(1, 55) | x.isna()).any(), axis=1)
if invalid_rows.any():
    logging.warning("Loại bỏ %d hàng có số ngoài phạm vi 1-55 hoặc NaN.", invalid_rows.sum())
    df = df[~invalid_rows]

# Chuyển đổi cột ngày sang datetime
df['Ngày Mở Thưởng'] = pd.to_datetime(df['Ngày Mở Thưởng'], format='%Y-%m-%d', errors='coerce')
if df['Ngày Mở Thưởng'].isna().any():
    logging.error("Có giá trị ngày không hợp lệ trong cột Ngày Mở Thưởng.")
    exit()

# Thêm các đặc trưng
df['Sum'] = df[['Num1', 'Num2', 'Num3', 'Num4', 'Num5', 'Num6']].sum(axis=1)
df['Mean'] = df[['Num1', 'Num2', 'Num3', 'Num4', 'Num5', 'Num6']].mean(axis=1)
df['Std'] = df[['Num1', 'Num2', 'Num3', 'Num4', 'Num5', 'Num6']].std(axis=1)

# Xử lý cột Giải Jackpot 1 nếu có
if 'Giải Jackpot 1' in df.columns:
    df['Giải Jackpot 1'] = pd.to_numeric(df['Giải Jackpot 1'], errors='coerce')
    logging.info("Đã xử lý cột Giải Jackpot 1 thành số.")

# Xác định ngày kỳ quay tiếp theo (Thứ 3, Thứ 5, Thứ 7)
latest_date = df['Ngày Mở Thưởng'].max()
def get_next_draw_date(current_date):
    weekday = current_date.weekday()
    if weekday == 1:  # Thứ 3 -> Thứ 5
        return current_date + timedelta(days=2)
    elif weekday == 3:  # Thứ 5 -> Thứ 7
        return current_date + timedelta(days=2)
    elif weekday == 5:  # Thứ 7 -> Thứ 3
        return current_date + timedelta(days=3)
    else:  # Lấy ngày quay gần nhất
        days_to_next = (1 - weekday) % 7 if weekday != 1 else 2
        return current_date + timedelta(days=days_to_next)

next_draw_date = get_next_draw_date(latest_date)
logging.info("Ngày mới nhất trong dữ liệu: %s", latest_date.strftime('%Y-%m-%d'))
logging.info("Kỳ quay tiếp theo: %s", next_draw_date.strftime('%Y-%m-%d'))

# Lấy dữ liệu số và đặc trưng
numbers_df = df[['Num1', 'Num2', 'Num3', 'Num4', 'Num5', 'Num6', 'Sum', 'Mean', 'Std']]

# --- Phân tích đặc trưng ---
# 1. Tần suất
def frequency_analysis(df, recent=False):
    df = df.tail(90) if recent and len(df) > 90 else df
    all_numbers = df[['Num1', 'Num2', 'Num3', 'Num4', 'Num5', 'Num6']].values.flatten()
    freq = Counter(n for n in all_numbers if 1 <= n <= 55)
    sorted_freq = sorted(freq.items(), key=lambda x: x[1], reverse=True)
    return sorted_freq[:6], sorted_freq[:10], freq

# 2. Cặp số
def pair_analysis(df):
    pairs = [tuple(sorted(row[['Num1', 'Num2', 'Num3', 'Num4', 'Num5', 'Num6']].values)) for _, row in df.iterrows()]
    pair_freq = Counter(p for p in (combinations(c, 2) for c in pairs) for p in p if all(1 <= x <= 55 for x in p))
    sorted_pairs = sorted(pair_freq.items(), key=lambda x: x[1], reverse=True)
    if not sorted_pairs:
        return [], []
    pair = sorted_pairs[0][0]
    related = []
    for _, row in df.iterrows():
        row_set = set(row[['Num1', 'Num2', 'Num3', 'Num4', 'Num5', 'Num6']].values)
        if set(pair).issubset(row_set):
            related.extend(n for n in row_set if n not in pair and 1 <= n <= 55)
    related_freq = Counter(related)
    top_related = [n for n, _ in sorted(related_freq.items(), key=lambda x: x[1], reverse=True)[:4]]
    predicted = sorted(list(pair) + top_related)
    return predicted[:6], sorted_pairs[:5]

# 3. Chu kỳ
def cycle_analysis(df):
    cycles = {i: [] for i in range(1, 56)}
    for idx, row in df.iterrows():
        for num in row[['Num1', 'Num2', 'Num3', 'Num4', 'Num5', 'Num6']].values:
            if 1 <= num <= 55:
                cycles[num].append(idx)
    predicted = []
    current_row = len(df) - 1
    for num in range(1, 56):
        cycle = cycles[num]
        if not cycle:
            continue
        gaps = np.diff(cycle)
        mean_gap = np.mean(gaps) if len(gaps) > 0 else 10  # Giả định khoảng cách trung bình nếu không đủ dữ liệu
        cycles_since_last = current_row - cycle[-1]
        likelihood = cycles_since_last / mean_gap if mean_gap > 0 else 0
        predicted.append((num, likelihood))
    predicted.sort(key=lambda x: x[1], reverse=True)
    return [n for n, _ in predicted[:6]], predicted[:10]

# 4. Nhóm số
def cluster_analysis(df):
    clusters = {'Thấp': range(1, 19), 'Trung': range(19, 37), 'Cao': range(37, 56)}
    counts = []
    for _, row in df.iterrows():
        c = {'Thấp': 0, 'Trung': 0, 'Cao': 0}
        for n in row[['Num1', 'Num2', 'Num3', 'Num4', 'Num5', 'Num6']].values:
            if n in clusters['Thấp']:
                c['Thấp'] += 1
            elif n in clusters['Trung']:
                c['Trung'] += 1
            elif n in clusters['Cao']:
                c['Cao'] += 1
        counts.append(c)
    return pd.DataFrame(counts).mean()

# 5. Chẵn/lẻ và tổng số
def even_odd_analysis(df):
    ratios = []
    sums = []
    for _, row in df.iterrows():
        valid_nums = [n for n in row[['Num1', 'Num2', 'Num3', 'Num4', 'Num5', 'Num6']].values if 1 <= n <= 55]
        even_count = sum(1 for n in valid_nums if n % 2 == 0)
        ratios.append(f"{even_count}/{6-even_count}")
        sums.append(sum(valid_nums))
    return Counter(ratios).most_common(5), np.mean(sums) if sums else 0

# 6. Kết hợp dự đoán
def combine_predictions(freq, pair, cycle, recent):
    all_nums = [n for n, _ in freq] + pair + cycle + [n for n, _ in recent]
    combined = Counter(n for n in all_nums if 1 <= n <= 55)
    sorted_combined = sorted(combined.items(), key=lambda x: (x[1], x[0]), reverse=True)
    return sorted([n for n, _ in sorted_combined[:6]])

# --- Mô hình LSTM ---
def prepare_lstm_data(df, lags=7):
    data = df[['Num1', 'Num2', 'Num3', 'Num4', 'Num5', 'Num6', 'Sum', 'Mean', 'Std']].values
    scaler = MinMaxScaler()
    data_scaled = scaler.fit_transform(data)
    
    X, y = [], []
    for i in range(lags, len(data_scaled)):
        X.append(data_scaled[i-lags:i])
        y.append(data_scaled[i, :6])  # Chỉ dự đoán 6 số
    X, y = np.array(X), np.array(y)
    
    train_size = int(0.8 * len(X))
    X_train, X_test = X[:train_size], X[train_size:]
    y_train, y_test = y[:train_size], y[train_size:]
    
    return X_train, y_train, X_test, y_test, scaler

def train_lstm(X_train, y_train, X_test, y_test):
    model = Sequential([
        Input(shape=(X_train.shape[1], X_train.shape[2])),
        LSTM(128, return_sequences=True),
        Dropout(0.2),
        LSTM(64),
        Dropout(0.2),
        Dense(32, activation='relu'),
        Dense(6, activation='sigmoid')  # Dự đoán 6 số
    ])
    model.compile(optimizer='adam', loss='mse')
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    
    history = model.fit(
        X_train, y_train,
        epochs=200,
        batch_size=32,
        validation_data=(X_test, y_test),
        callbacks=[early_stopping],
        verbose=0
    )
    
    return model, history

def evaluate_f1_score(y_true, y_pred):
    y_true = np.round(y_true).astype(int).flatten()
    y_pred = np.round(y_pred).astype(int).flatten()
    return f1_score(y_true, y_pred, average='micro', zero_division=0)

def lstm_prediction(df, lags=7):
    X_train, y_train, X_test, y_test, scaler = prepare_lstm_data(df, lags)
    model, history = train_lstm(X_train, y_train, X_test, y_test)
    
    y_pred_scaled = model.predict(X_test, verbose=0)
    y_pred = scaler.inverse_transform(np.hstack([y_pred_scaled, np.zeros((y_pred_scaled.shape[0], 3))]))[:, :6]
    f1 = evaluate_f1_score(scaler.inverse_transform(np.hstack([y_test, np.zeros((y_test.shape[0], 3))]))[:, :6], y_pred)
    final_loss = history.history['loss'][-1]
    final_val_loss = history.history['val_loss'][-1]
    logging.info("LSTM - Số epoch thực tế: %d", len(history.history['loss']))
    logging.info("LSTM - Loss cuối: %.4f, Validation Loss cuối: %.4f", final_loss, final_val_loss)
    logging.info("LSTM - F1-score trên tập test: %.4f", f1)
    
    last_sequence = df[['Num1', 'Num2', 'Num3', 'Num4', 'Num5', 'Num6', 'Sum', 'Mean', 'Std']].values[-lags:]
    last_sequence_scaled = scaler.transform(last_sequence)
    last_sequence_scaled = last_sequence_scaled.reshape(1, lags, 9)
    
    pred_scaled = model.predict(last_sequence_scaled, verbose=0)
    pred = scaler.inverse_transform(np.hstack([pred_scaled, np.zeros((pred_scaled.shape[0], 3))]))[:, :6]
    pred = np.round(pred).astype(int)
    
    pred = np.clip(pred, 1, 55)
    pred = np.unique(pred)
    while len(pred) < 6:
        pred = np.append(pred, np.random.randint(1, 56))
    return sorted(pred[:6]), f1, final_loss, final_val_loss

# Thực hiện phân tích
freq_nums, freq_details, _ = frequency_analysis(numbers_df)
recent_nums, recent_details, _ = frequency_analysis(numbers_df, recent=True)
pair_nums, pair_details = pair_analysis(numbers_df)
cycle_nums, cycle_details = cycle_analysis(numbers_df)
cluster_avg = cluster_analysis(numbers_df)
even_odd_ratios, avg_sum = even_odd_analysis(numbers_df)
final_nums = combine_predictions(freq_nums, pair_nums, cycle_nums, recent_nums)
lstm_pred, f1_score_lstm, final_loss, final_val_loss = lstm_prediction(numbers_df)

# Lưu kết quả dự đoán
predictions = {
    'Ngày Dự Đoán': [next_draw_date.strftime('%Y-%m-%d')],
    'Tần Suất': [freq_nums],
    'Tần Suất Gần Đây': [recent_nums],
    'Cặp Số': [pair_nums],
    'Chu Kỳ': [cycle_nums],
    'Kết Hợp': [final_nums],
    'LSTM': [lstm_pred],
    'F1-Score LSTM': [f1_score_lstm],
    'Loss LSTM': [final_loss],
    'Val Loss LSTM': [final_val_loss]
}
predictions_df = pd.DataFrame(predictions)
try:
    predictions_df.to_csv(output_predictions_path, index=False, encoding='utf-8', sep='\t')
    logging.info("Kết quả dự đoán đã được lưu vào %s", output_predictions_path)
except Exception as e:
    logging.error("Lỗi khi lưu kết quả dự đoán: %s", e)

# Đánh giá mô hình
logging.info("\nĐánh giá mô hình:")
logging.info("Tần suất, cặp số, chu kỳ, kết hợp: Dựa trên thống kê, không có F1-score.")
logging.info("LSTM: F1-score = %.4f, Loss = %.4f, Validation Loss = %.4f", f1_score_lstm, final_loss, final_val_loss)
logging.info("Nhận xét: F1-score thấp (<0.1) là bình thường do tính ngẫu nhiên của Vietlott Power 6/55. F1 > 0.05 đã là khả quan.")

# In kết quả
logging.info(f"\nDỰ ĐOÁN KỲ QUAY VIETLOTT POWER 6/55 ({next_draw_date.strftime('%Y-%m-%d %H:%M:%S')})\n")

logging.info("1. PHÂN TÍCH NHÓM SỐ")
logging.info("Tỷ lệ trung bình mỗi nhóm:\n%s", cluster_avg.to_string())
logging.info("")

logging.info("2. PHÂN TÍCH CHẴN/LẺ")
logging.info("Tỷ lệ chẵn/lẻ phổ biến:")
for r, c in even_odd_ratios:
    logging.info("%s: %d lần", r, c)
logging.info("Tổng trung bình: %.2f", avg_sum)
logging.info("")

logging.info("3. DỰ ĐOÁN DỰA TRÊN TẦN SUẤT")
logging.info("Bộ số dự đoán: %s", [n for n, _ in freq_nums])
logging.info("Chi tiết (Top 10):")
for n, c in freq_details:
    logging.info("Số %d: %d lần", n, c)
logging.info("")

logging.info("4. DỰ ĐOÁN DỰA TRÊN TẦN SUẤT GẦN ĐÂY (3 tháng)")
logging.info("Bộ số dự đoán: %s", [n for n, _ in recent_nums])
logging.info("Chi tiết (Top 10):")
for n, c in recent_details:
    logging.info("Số %d: %d lần", n, c)
logging.info("")

logging.info("5. DỰ ĐOÁN DỰA TRÊN CẶP SỐ")
logging.info("Bộ số dự đoán: %s", pair_nums)
logging.info("Chi tiết cặp số (Top 5):")
for p, c in pair_details:
    logging.info("Cặp %s: %d lần", p, c)
logging.info("")

logging.info("6. DỰ ĐOÁN DỰA TRÊN CHU KỲ")
logging.info("Bộ số dự đoán: %s", cycle_nums)
logging.info("Chi tiết (Top 10):")
for n, l in cycle_details:
    logging.info("Số %d: Xác suất chu kỳ = %.2f", n, l)
logging.info("")

logging.info("7. BỘ SỐ DỰ ĐOÁN KẾT HỢP")
logging.info("Bộ số cuối cùng: %s", final_nums)
logging.info("")

logging.info("8. DỰ ĐOÁN DỰA TRÊN LSTM")
logging.info("Bộ số dự đoán: %s", lstm_pred)
logging.info("F1-score: %.4f, Loss: %.4f, Val Loss: %.4f", f1_score_lstm, final_loss, final_val_loss)
logging.info("\nLưu ý: Dự đoán chỉ mang tính tham khảo. Chúc may mắn!\n")
# Out:
# 2025-06-21 14:21:32,450 - INFO - Ngày mới nhất trong dữ liệu: 2025-06-17
# 2025-06-21 14:21:32,451 - INFO - Kỳ quay tiếp theo: 2025-06-19
# 2025-06-21 14:21:43,252 - INFO - LSTM - Số epoch thực tế: 25
# 2025-06-21 14:21:43,253 - INFO - LSTM - Loss cuối: 0.0326, Validation Loss cuối: 0.0345
# 2025-06-21 14:21:43,254 - INFO - LSTM - F1-score trên tập test: 0.0472
# 2025-06-21 14:21:43,343 - INFO -
# Đánh giá mô hình:
# 2025-06-21 14:21:43,345 - INFO - Tần suất, cặp số, chu kỳ, kết hợp: Dựa trên thống kê, không có F1-score.
# 2025-06-21 14:21:43,346 - INFO - LSTM: F1-score = 0.0472, Loss = 0.0326, Validation Loss = 0.0345
# 2025-06-21 14:21:43,347 - INFO - Nhận xét: F1-score thấp (<0.1) là bình thường do tính ngẫu nhiên của Vietlott. F1 > 0.05 đã là khả quan.
# 2025-06-21 14:21:43,347 - INFO -
# DỰ ĐOÁN KỲ QUAY VIETLOTT POWER 6/55 (2025-06-19 00:00:00)
#
# 2025-06-21 14:21:43,348 - INFO - 1. PHÂN TÍCH NHÓM SỐ
# 2025-06-21 14:21:43,349 - INFO - Tỷ lệ trung bình mỗi nhóm:
# Thấp     1.911130
# Trung    1.950997
# Cao      2.137874
# 2025-06-21 14:21:43,349 - INFO -
# 2025-06-21 14:21:43,349 - INFO - 2. PHÂN TÍCH CHẴN/LẺ
# 2025-06-21 14:21:43,351 - INFO - Tỷ lệ chẵn/lẻ phổ biến:
# 2025-06-21 14:21:43,353 - INFO - 3/3: 402 lần
# 2025-06-21 14:21:43,353 - INFO - 4/2: 301 lần
# 2025-06-21 14:21:43,354 - INFO - 2/4: 287 lần
# 2025-06-21 14:21:43,355 - INFO - 1/5: 113 lần
# 2025-06-21 14:21:43,356 - INFO - 5/1: 74 lần
# 2025-06-21 14:21:43,356 - INFO - Tổng trung bình: 170.08
# 2025-06-21 14:21:43,358 - INFO -
# 2025-06-21 14:21:43,359 - INFO - 3. DỰ ĐOÁN DỰA TRÊN TẦN SUẤT
# 2025-06-21 14:21:43,360 - INFO - Bộ số dự đoán: [np.int64(41), np.int64(51), np.int64(22), np.int64(34), np.int64(29), np.int64(32)]
# 2025-06-21 14:21:43,361 - INFO - Chi tiết (Top 10):
# 2025-06-21 14:21:43,361 - INFO - Số 41: 155 lần
# 2025-06-21 14:21:43,362 - INFO - Số 51: 153 lần
# 2025-06-21 14:21:43,363 - INFO - Số 22: 147 lần
# 2025-06-21 14:21:43,363 - INFO - Số 34: 145 lần
# 2025-06-21 14:21:43,364 - INFO - Số 29: 145 lần
# 2025-06-21 14:21:43,365 - INFO - Số 32: 143 lần
# 2025-06-21 14:21:43,366 - INFO - Số 47: 143 lần
# 2025-06-21 14:21:43,367 - INFO - Số 23: 143 lần
# 2025-06-21 14:21:43,367 - INFO - Số 43: 142 lần
# 2025-06-21 14:21:43,368 - INFO - Số 11: 141 lần
# 2025-06-21 14:21:43,368 - INFO -
# 2025-06-21 14:21:43,369 - INFO - 4. DỰ ĐOÁN DỰA TRÊN TẦN SUẤT GẦN ĐÂY (3 tháng)
# 2025-06-21 14:21:43,369 - INFO - Bộ số dự đoán: [np.int64(36), np.int64(50), np.int64(35), np.int64(41), np.int64(7), np.int64(8)]
# 2025-06-21 14:21:43,370 - INFO - Chi tiết (Top 10):
# 2025-06-21 14:21:43,372 - INFO - Số 36: 17 lần
# 2025-06-21 14:21:43,374 - INFO - Số 50: 15 lần
# 2025-06-21 14:21:43,377 - INFO - Số 35: 15 lần
# 2025-06-21 14:21:43,377 - INFO - Số 41: 15 lần
# 2025-06-21 14:21:43,378 - INFO - Số 7: 14 lần
# 2025-06-21 14:21:43,379 - INFO - Số 8: 13 lần
# 2025-06-21 14:21:43,379 - INFO - Số 44: 13 lần
# 2025-06-21 14:21:43,380 - INFO - Số 24: 13 lần
# 2025-06-21 14:21:43,381 - INFO - Số 32: 13 lần
# 2025-06-21 14:21:43,381 - INFO - Số 1: 13 lần
# 2025-06-21 14:21:43,382 - INFO -
# 2025-06-21 14:21:43,384 - INFO - 5. DỰ ĐOÁN DỰA TRÊN CẶP SỐ
# 2025-06-21 14:21:43,387 - INFO - Bộ số dự đoán: [np.int64(3), np.int64(14), np.int64(19), np.int64(32), np.int64(40), np.int64(41)]
# 2025-06-21 14:21:43,388 - INFO - Chi tiết cặp số (Top 5):
# 2025-06-21 14:21:43,389 - INFO - Cặp (np.int64(3), np.int64(41)): 27 lần
# 2025-06-21 14:21:43,390 - INFO - Cặp (np.int64(9), np.int64(54)): 25 lần
# 2025-06-21 14:21:43,390 - INFO - Cặp (np.int64(42), np.int64(51)): 25 lần
# 2025-06-21 14:21:43,391 - INFO - Cặp (np.int64(32), np.int64(51)): 24 lần
# 2025-06-21 14:21:43,391 - INFO - Cặp (np.int64(11), np.int64(22)): 23 lần
# 2025-06-21 14:21:43,392 - INFO -
# 2025-06-21 14:21:43,394 - INFO - 6. DỰ ĐOÁN DỰA TRÊN CHU KỲ
# 2025-06-21 14:21:43,395 - INFO - Bộ số dự đoán: [2, 3, 8, 17, 18, 21]
# 2025-06-21 14:21:43,396 - INFO - Chi tiết (Top 10):
# 2025-06-21 14:21:43,397 - INFO - Số 2: Xác suất chu kỳ = 1.00
# 2025-06-21 14:21:43,400 - INFO - Số 3: Xác suất chu kỳ = 1.00
# 2025-06-21 14:21:43,401 - INFO - Số 8: Xác suất chu kỳ = 1.00
# 2025-06-21 14:21:43,402 - INFO - Số 17: Xác suất chu kỳ = 1.00
# 2025-06-21 14:21:43,403 - INFO - Số 18: Xác suất chu kỳ = 1.00
# 2025-06-21 14:21:43,403 - INFO - Số 21: Xác suất chu kỳ = 1.00
# 2025-06-21 14:21:43,404 - INFO - Số 22: Xác suất chu kỳ = 1.00
# 2025-06-21 14:21:43,405 - INFO - Số 28: Xác suất chu kỳ = 1.00
# 2025-06-21 14:21:43,405 - INFO - Số 29: Xác suất chu kỳ = 1.00
# 2025-06-21 14:21:43,407 - INFO - Số 35: Xác suất chu kỳ = 1.00
# 2025-06-21 14:21:43,408 - INFO -
# 2025-06-21 14:21:43,408 - INFO - 7. BỘ SỐ DỰ ĐOÁN KẾT HỢP
# 2025-06-21 14:21:43,409 - INFO - Bộ số cuối cùng: [np.int64(3), 8, np.int64(32), np.int64(41), np.int64(50), np.int64(51)]
# 2025-06-21 14:21:43,410 - INFO -
# 2025-06-21 14:21:43,411 - INFO - 8. DỰ ĐOÁN DỰA TRÊN LSTM
# 2025-06-21 14:21:43,412 - INFO - Bộ số dự đoán: [np.int64(8), np.int64(16), np.int64(24), np.int64(32), np.int64(40), np.int64(48)]
# 2025-06-21 14:21:43,413 - INFO - F1-score: 0.0472, Loss: 0.0326, Val Loss: 0.0345
# 2025-06-21 14:21:43,413 - INFO -
# Lưu ý: Dự đoán chỉ mang tính tham khảo. Chúc may mắn!
